# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
print(df.head())
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
#df should be converted to dict before inserting to mongodb
data_dict = df.to_dict(orient='records')

# %%
DB_NAME = "proj1"
COLLECTION_NAME = "proj1"
CONNECTION_URL = "mongodb+srv://khalidm8746_db_user:dlJOXC4olWMq9CQF@cluster0.0abjrtz.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# %%
#uploading to mongo

rec=collection.insert_many(data_dict)
